# %%
# some libraries that you may or may not use
# feel free to import other libraries if necessary
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.linear_model import SGDRegressor, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\mahmu\anaconda3\envs\cs667\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\mahmu\anaconda3\envs\cs667\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\mahmu\anaconda3\envs\cs667\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mahmu\anaconda3\envs\cs667\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mahmu\anaconda3\envs\cs667\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# TODO: calculate and return Root Mean Square Error (RMSE)
    # Hint: you can either code yourself or use the mean_squared_error function from sklearn.metrics

# %%
def RMSE(yHat, y):
    # Calculate RMSE manually
    mse = mean_squared_error(y_pred, yTest)  # Mean Squared Error
    rmse = np.sqrt(mse)  # Root Mean Square Error
    return rmse

# %%
def RMSE(yHat, y):
    return root_mean_squared_error(y_pred, yTest)

# %%
# load the data (the UCI forestfires dataset)
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv")
x = df.iloc[:, 0:12]
y = df.iloc[:, 12:13] # last column as the label column 
x.sample(5)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 230  4  4   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0
# 187  1  5   sep  mon  90.9  126.5  686.5   7.0  21.0  42   2.2   0.0
# 249  3  4   aug  wed  93.1  157.3  666.7  13.5  21.7  40   0.4   0.0
# 299  6  5   jun  sat  53.4   71.0  233.8   0.4  10.6  90   2.7   0.0
# 471  4  3   may  fri  89.6   25.4   73.7   5.7  18.0  40   4.0   0.0

# %%
# some preprocessing
# convert `month' and `day' to numerical values
le = preprocessing.LabelEncoder()
x["month"] = le.fit_transform(x["month"])
x["day"] = le.fit_transform(x["day"])

x.sample(5)
# Out:
#      X  Y  month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 490  4  4      1    6  95.1  141.3  605.8  17.7  28.7  33   4.0   0.0
# 343  8  6     11    1  91.5  130.1  807.1   7.5  15.9  51   4.5   0.0
# 360  6  5     11    0  92.5  122.0  789.7  10.2  18.4  42   2.2   0.0
# 152  3  4      5    2  90.1   51.2  424.1   6.2  24.6  43   1.8   0.0
# 464  6  4      3    5  75.1    4.4   16.2   1.9   5.1  77   5.4   0.0

# %%
# model construction, training, and evaluation
# split the data into training and test sets
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.33, random_state=42)

# TODO: 
# (1) build and train a linear model on the train set
# (2) calculate the RMSE error on the test set (use the function you defined earlier)

# Create a linear regression model
model1 = LinearRegression()
# Train the model on the training set
model1.fit(xTrain, yTrain)
# Make predictions on the test set
y_pred = model1.predict(xTest)
# Evaluate the model
mse = mean_squared_error(y_pred, yTest)
rmse = np.sqrt(mse)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 7792.702532101998
# Root Mean Squared Error: 88.27628521920255

# %%
#Again create a Linear Regression Model
model2 = LinearRegression()
# Train the model on the training set
model2.fit(xTrain, yTrain)
# Make predictions on the test set
y_pred = model2.predict(xTest)
# Evaluate the model
RMSE = root_mean_squared_error(y_pred, yTest)
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 88.27628521920255
